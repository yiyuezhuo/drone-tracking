# %%
# Ref to https://www.learnopencv.com/deep-learning-based-object-detection-using-yolov3-with-opencv-python-c/

# %load_ext autoreload
# %autoreload 2

# %%
import shutil

# %%
from drone_utils import *
# Out:
# OpenCV version: 4.1.0
# load ../yolo-cfg/yolov3-tiny-bin_obj.cfg backup/yolov3-tiny-bin_obj_final.weights
# ['drone']

# %%
frame,classIds,confidences,boxes = preprocess(img_path='5/thumb00100.png')

# %%
plt.figure(figsize=(12,12))
plt.imshow(frame)

# %%
plt.figure(figsize=(12,12))
show_detection2(frame, boxes)

# %%
batch_detect('4/*.png', '4_results', figsize=(12,12))
# Out:
# OpenCV version: 4.1.0
# load ../yolo-cfg/yolov3-tiny-bin_obj.cfg backup/yolov3-tiny-bin_obj_final.weights
# ['drone']

# %%
# %%time
batch_detect('5/*.png', '5_results', figsize=(12,12))
# Out:
# CPU times: user 4min 3s, sys: 891 ms, total: 4min 3s
# Wall time: 1min 57s

# %%
# %%time
batch_detect('6/*.png', '6_results', figsize=(12,12))
# Out:
# CPU times: user 1min 36s, sys: 349 ms, total: 1min 37s
# Wall time: 48.3 s
